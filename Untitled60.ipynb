# %%
import pandas as pd
import numpy as np
import sklearn
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv("https://raw.githubusercontent.com/dsrscientist/DSData/master/happiness_score_dataset.csv")

# %%
df
# Out:
#          Country                           Region  Happiness Rank  \
# 0    Switzerland                   Western Europe               1
# 1        Iceland                   Western Europe               2
# 2        Denmark                   Western Europe               3
# 3         Norway                   Western Europe               4
# 4         Canada                    North America               5
# ..           ...                              ...             ...
# 153       Rwanda               Sub-Saharan Africa             154
# 154        Benin               Sub-Saharan Africa             155
# 155        Syria  Middle East and Northern Africa             156
# 156      Burundi               Sub-Saharan Africa             157
# 157         Togo               Sub-Saharan Africa             158
#
#      Happiness Score  Standard Error  Economy (GDP per Capita)   Family  \
# 0              7.587         0.03411                   1.39651  1.34951
# ...

# %%
df.columns
# Out:
# Index(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom', 'Trust (Government Corruption)',
#        'Generosity', 'Dystopia Residual'],
#       dtype='object')

# %%
df.describe()
# Out:
#        Happiness Rank  Happiness Score  Standard Error  \
# count      158.000000       158.000000      158.000000
# mean        79.493671         5.375734        0.047885
# std         45.754363         1.145010        0.017146
# min          1.000000         2.839000        0.018480
# 25%         40.250000         4.526000        0.037268
# 50%         79.500000         5.232500        0.043940
# 75%        118.750000         6.243750        0.052300
# max        158.000000         7.587000        0.136930
#
#        Economy (GDP per Capita)      Family  Health (Life Expectancy)  \
# count                158.000000  158.000000                158.000000
# mean                   0.846137    0.991046                  0.630259
# std                    0.403121    0.272369                  0.247078
# min                    0.000000    0.000000                  0.000000
# 25%                    0.545808    0.856823                  0.439185
# ...

# %%
df.isnull().sum()
# Out:
# Country                          0
# Region                           0
# Happiness Rank                   0
# Happiness Score                  0
# Standard Error                   0
# Economy (GDP per Capita)         0
# Family                           0
# Health (Life Expectancy)         0
# Freedom                          0
# Trust (Government Corruption)    0
# Generosity                       0
# Dystopia Residual                0
# dtype: int64

# %%
plt.figure(figsize = (10,5))
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df['Happiness Score'].unique()
# Out:
# array([7.587, 7.561, 7.527, 7.522, 7.427, 7.406, 7.378, 7.364, 7.286,
#        7.284, 7.278, 7.226, 7.2  , 7.187, 7.119, 6.983, 6.946, 6.94 ,
#        6.937, 6.901, 6.867, 6.853, 6.81 , 6.798, 6.786, 6.75 , 6.67 ,
#        6.611, 6.575, 6.574, 6.505, 6.485, 6.477, 6.455, 6.411, 6.329,
#        6.302, 6.298, 6.295, 6.269, 6.168, 6.13 , 6.123, 6.003, 5.995,
#        5.987, 5.984, 5.975, 5.96 , 5.948, 5.89 , 5.889, 5.878, 5.855,
#        5.848, 5.833, 5.828, 5.824, 5.813, 5.791, 5.77 , 5.759, 5.754,
#        5.716, 5.709, 5.695, 5.689, 5.605, 5.589, 5.548, 5.477, 5.474,
#        5.429, 5.399, 5.36 , 5.332, 5.286, 5.268, 5.253, 5.212, 5.194,
#        5.192, 5.14 , 5.129, 5.124, 5.123, 5.102, 5.098, 5.073, 5.057,
#        5.013, 5.007, 4.971, 4.959, 4.949, 4.898, 4.885, 4.876, 4.874,
#        4.867, 4.857, 4.839, 4.8  , 4.788, 4.786, 4.739, 4.715, 4.694,
#        4.686, 4.681, 4.677, 4.642, 4.633, 4.61 , 4.571, 4.565, 4.55 ,
# ...

# %%
df['Happiness Score'].nunique()
# Out:
# 157

# %%
df['Economy (GDP per Capita)'].nunique()
# Out:
# 158

# %%
df['Freedom'].nunique()
# Out:
# 158

# %%
df['Family'].nunique()
# Out:
# 158

# %% [markdown]
# # EDA Analysis

# %%
plt.figure(figsize=(20,12))
sns.barplot('Country','Happiness Score',data=df)
plt.ylabel='Happiness Score'
plt.xplot='Country'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
plt.figure(figsize=(20,12))
sns.barplot('Region','Happiness Score',data=df)
plt.ylabel='Happiness Score'
plt.xplot='Region'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# Australia and New Zealand have highest happiness score and sub saharan africa has lowest happiness score as per the graph

# %%
plt.figure(figsize=(20,12))
sns.barplot('Happiness Score','Happiness Rank',data=df)
plt.xlabel='Happiness Score'
plt.ylabel='Happiness Rank'
plt.title= " Graph between Happiness Rank and Happiness Score"
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# Happiness Rank is decreasing with decrease in Happiness score

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Standard Error','Happiness Score',data=df)
plt.xlabel='Standard Error'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# Maximum standard error is in the range of 0.03 to 0.06

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Economy (GDP per Capita)','Happiness Score',data=df)
plt.xlabel='Economy (GDP per Capita)'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# Happiness Score is increasing with increase in Economy

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Family','Happiness Score',data=df)
plt.xlabel='Family'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# With increase in family Hapiness score is increasing

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Health (Life Expectancy)','Happiness Score',data=df)
plt.xlabel='Health (Life Expectancy)'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# The more the health (Life Expectancy) the higher the Hapiness score

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Freedom','Happiness Score',data=df)
plt.xlabel='Freedom'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# With increase in Freedom Happiness score is increasing

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Trust (Government Corruption)','Happiness Score',data=df)
plt.xlabel='Trust(Government Corruption)'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# the lower the corruption the higher the hapiness score.

# %%
plt.figure(figsize=(8,5))
sns.scatterplot('Generosity','Happiness Score',data=df)
plt.xlabel='Generosity'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %% [markdown]
# the happiness score is higher in lower range of generosity

# %%
plt.figure(figsize=(10,6))
sns.scatterplot('Dystopia Residual','Happiness Score',data=df)
plt.xlabel='Dystopia Residual'
plt.ylabel='Happiness Score'
plt.legend(loc='upper right',fontsize='10')
plt.show()
# Out:
# C:\Users\91789\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# No handles with labels found to put in legend.

# %%
sns.pairplot(data=df)

# %%
sns.heatmap(df.corr(),annot=True,fmt='0.2f')
plt.figure(figsize=(50,30))
plt.show()

# %%
df.corr()
# Out:
#                                Happiness Rank  Happiness Score  \
# Happiness Rank                       1.000000        -0.992105
# Happiness Score                     -0.992105         1.000000
# Standard Error                       0.158516        -0.177254
# Economy (GDP per Capita)            -0.785267         0.780966
# Family                              -0.733644         0.740605
# Health (Life Expectancy)            -0.735613         0.724200
# Freedom                             -0.556886         0.568211
# Trust (Government Corruption)       -0.372315         0.395199
# Generosity                          -0.160142         0.180319
# Dystopia Residual                   -0.521999         0.530474
#
#                                Standard Error  Economy (GDP per Capita)  \
# Happiness Rank                       0.158516                 -0.785267
# Happiness Score                     -0.177254                  0.780966
# ...

# %%
df.corr()['Happiness Score'].sort_values()
# Out:
# Happiness Rank                  -0.992105
# Standard Error                  -0.177254
# Generosity                       0.180319
# Trust (Government Corruption)    0.395199
# Dystopia Residual                0.530474
# Freedom                          0.568211
# Health (Life Expectancy)         0.724200
# Family                           0.740605
# Economy (GDP per Capita)         0.780966
# Happiness Score                  1.000000
# Name: Happiness Score, dtype: float64

# %%
import statsmodels.api as sm

# %%
y=df['Happiness Score']
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 153    3.465
# 154    3.340
# 155    3.006
# 156    2.905
# 157    2.839
# Name: Happiness Score, Length: 158, dtype: float64

# %%
x= df.iloc[:,4:-1]
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 153         0.03464                   0.22208  0.77370
# 154         0.03656                   0.28665  0.35386
# 155         0.05015                   0.66320  0.47489
# 156         0.08658                   0.01530  0.41587
# 157         0.06727                   0.20868  0.13995
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
x= sm.add_constant(x)
model=sm.OLS(y,x).fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:        Happiness Score   R-squared:                       0.779
# Model:                            OLS   Adj. R-squared:                  0.768
# Method:                 Least Squares   F-statistic:                     75.39
# Date:                Sun, 28 Aug 2022   Prob (F-statistic):           6.31e-46
# Time:                        13:05:44   Log-Likelihood:                -125.94
# No. Observations:                 158   AIC:                             267.9
# Df Residuals:                     150   BIC:                             292.4
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                                     coef    std err          t      P>|t|      [0.025      0.975]
# -------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# as p score is less than 0.5 there is no multi colinearity.

# %%
colist= df.columns.values
colist
# Out:
# array(['Country', 'Region', 'Happiness Rank', 'Happiness Score',
#        'Standard Error', 'Economy (GDP per Capita)', 'Family',
#        'Health (Life Expectancy)', 'Freedom',
#        'Trust (Government Corruption)', 'Generosity', 'Dystopia Residual'],
#       dtype=object)

# %%
ncol=30
nrow= 15
plt.figure(figsize=(ncol,3*ncol))
for i in range(2,len(colist)):
    plt.subplot(nrow,ncol,i+1)
    sns.boxplot(data=df[colist[i]],orient='v')
    plt.tight_layout()

# %% [markdown]
# There are outliers in standard error and Trust and Generosity

# %% [markdown]
#  # Removing skewness

# %%
import scipy
from scipy import stats
import scipy.stats as stats
from scipy.stats import zscore

# %%
df1=df.iloc[:,2:]
df1
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 153             154            3.465         0.03464
# 154             155            3.340         0.03656
# 155             156            3.006         0.05015
# 156             157            2.905         0.08658
# 157             158            2.839         0.06727
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
np.abs(zscore(df1))
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0          1.721000         1.937360        0.805926
# 1          1.699075         1.914581        0.055889
# 2          1.677149         1.884792        0.854487
# 3          1.655224         1.880411        0.531526
# 4          1.633299         1.797179        0.722845
# ..              ...              ...             ...
# 153        1.633576         1.674055        0.774917
# 154        1.655501         1.783571        0.662582
# 155        1.677427         2.076199        0.132534
# 156        1.699352         2.164688        2.263962
# 157        1.721277         2.222513        1.134182
#
#      Economy (GDP per Capita)    Family  Health (Life Expectancy)   Freedom  \
# 0                    1.369621  1.320281                  1.263408  1.577438
# 1                    1.135226  1.514458                  1.289434  1.332456
# 2                    1.192861  1.361054                  0.992229  1.469659
# ...

# %%
z=np.abs(zscore(df1))
z.shape
# Out:
# (158, 10)

# %%
np.where(z>3)
# Out:
# (array([ 27,  40,  64, 115, 128, 147, 153, 155, 157], dtype=int64),
#  array([7, 2, 2, 2, 8, 4, 7, 9, 4], dtype=int64))

# %%
df_new=df1[(z<3).all(axis=1)]
df_new
# Out:
#      Happiness Rank  Happiness Score  Standard Error  \
# 0                 1            7.587         0.03411
# 1                 2            7.561         0.04884
# 2                 3            7.527         0.03328
# 3                 4            7.522         0.03880
# 4                 5            7.427         0.03553
# ..              ...              ...             ...
# 150             151            3.655         0.05141
# 151             152            3.587         0.04324
# 152             153            3.575         0.03084
# 154             155            3.340         0.03656
# 156             157            2.905         0.08658
#
#      Economy (GDP per Capita)   Family  Health (Life Expectancy)  Freedom  \
# 0                     1.39651  1.34951                   0.94143  0.66557
# 1                     1.30232  1.40223                   0.94784  0.62877
# 2                     1.32548  1.36058                   0.87464  0.64938
# ...

# %%
df2=df.iloc[:,:2]
df2
# Out:
#          Country                           Region
# 0    Switzerland                   Western Europe
# 1        Iceland                   Western Europe
# 2        Denmark                   Western Europe
# 3         Norway                   Western Europe
# 4         Canada                    North America
# ..           ...                              ...
# 153       Rwanda               Sub-Saharan Africa
# 154        Benin               Sub-Saharan Africa
# 155        Syria  Middle East and Northern Africa
# 156      Burundi               Sub-Saharan Africa
# 157         Togo               Sub-Saharan Africa
#
# [158 rows x 2 columns]

# %%
df2.drop([27,40,64,115,128,147,153,155,157],axis=0)
# Out:
#           Country              Region
# 0     Switzerland      Western Europe
# 1         Iceland      Western Europe
# 2         Denmark      Western Europe
# 3          Norway      Western Europe
# 4          Canada       North America
# ..            ...                 ...
# 150   Ivory Coast  Sub-Saharan Africa
# 151  Burkina Faso  Sub-Saharan Africa
# 152   Afghanistan       Southern Asia
# 154         Benin  Sub-Saharan Africa
# 156       Burundi  Sub-Saharan Africa
#
# [149 rows x 2 columns]

# %%
frame=[df2,df_new]

# %%
df3=pd.concat(frame,join='inner',axis=1)
df3
# Out:
#           Country              Region  Happiness Rank  Happiness Score  \
# 0     Switzerland      Western Europe               1            7.587
# 1         Iceland      Western Europe               2            7.561
# 2         Denmark      Western Europe               3            7.527
# 3          Norway      Western Europe               4            7.522
# 4          Canada       North America               5            7.427
# ..            ...                 ...             ...              ...
# 150   Ivory Coast  Sub-Saharan Africa             151            3.655
# 151  Burkina Faso  Sub-Saharan Africa             152            3.587
# 152   Afghanistan       Southern Asia             153            3.575
# 154         Benin  Sub-Saharan Africa             155            3.340
# 156       Burundi  Sub-Saharan Africa             157            2.905
#
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# ...

# %%
print('old_DataFrame',df.shape)
print("New_DataFrame",df3.shape)
# Out:
# old_DataFrame (158, 12)
# New_DataFrame (149, 12)

# %%
data_loss=(158*12-149*12)/(158*12)*100
data_loss
# Out:
# 5.69620253164557

# %% [markdown]
# # skewness checking

# %%
df3.skew()
# Out:
# C:\Users\91789\AppData\Local\Temp/ipykernel_1784/3045539152.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df3.skew()
# Happiness Rank                   0.003268
# Happiness Score                  0.169740
# Standard Error                   1.243048
# Economy (GDP per Capita)        -0.390657
# Family                          -0.811340
# Health (Life Expectancy)        -0.747711
# Freedom                         -0.400867
# Trust (Government Corruption)    1.272530
# Generosity                       0.654710
# Dystopia Residual               -0.021144
# dtype: float64

# %% [markdown]
# standard error and Trust have high skewness

# %%
Standard_error= np.sqrt(df3['Standard Error'])
Standard_error.skew()
# Out:
# 0.7173474294227211

# %%
Trust=np.sqrt(df3['Trust (Government Corruption)'])
Trust.skew()
# Out:
# 0.437253236061777

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import power_transform

# %%
x=df3.iloc[:,4:]
x
# Out:
#      Standard Error  Economy (GDP per Capita)   Family  \
# 0           0.03411                   1.39651  1.34951
# 1           0.04884                   1.30232  1.40223
# 2           0.03328                   1.32548  1.36058
# 3           0.03880                   1.45900  1.33095
# 4           0.03553                   1.32629  1.32261
# ..              ...                       ...      ...
# 150         0.05141                   0.46534  0.77115
# 151         0.04324                   0.25812  0.85188
# 152         0.03084                   0.31982  0.30285
# 154         0.03656                   0.28665  0.35386
# 156         0.08658                   0.01530  0.41587
#
#      Health (Life Expectancy)  Freedom  Trust (Government Corruption)  \
# 0                     0.94143  0.66557                        0.41978
# 1                     0.94784  0.62877                        0.14145
# 2                     0.87464  0.64938                        0.48357
# ...

# %%
y=df3.iloc[:,3]
y
# Out:
# 0      7.587
# 1      7.561
# 2      7.527
# 3      7.522
# 4      7.427
#        ...
# 150    3.655
# 151    3.587
# 152    3.575
# 154    3.340
# 156    2.905
# Name: Happiness Score, Length: 149, dtype: float64

# %%
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.95033703,  1.49245411,  1.65888016, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.00912496, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078528, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738878, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044293, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.90641014, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
StandardScaler().fit_transform(x)
# Out:
# array([[-0.95033703,  1.49245411,  1.65888016, ...,  1.81762514,
#          0.65957855,  0.75525527],
#        [ 0.37856182,  1.19406711,  2.00912496, ...,  0.32967608,
#          1.56260401,  1.11116834],
#        [-1.04140135,  1.26661161,  1.73078528, ...,  1.95339957,
#          0.97722591,  0.70649452],
#        ...,
#        [-1.32081011, -1.36521585, -2.08738878, ..., -0.19284339,
#          1.13425805, -0.32711524],
#        [-0.69272644, -1.43304072, -2.01044293, ..., -0.4344978 ,
#         -0.31207994, -0.93216364],
#        [ 2.17876604, -1.93874732, -1.90641014, ..., -0.14727363,
#         -0.17248608, -0.55359236]])

# %%
x.mean()
# Out:
# 4.470696743457006e-18

# %%
x.std()
# Out:
# 1.0

# %%
 x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=42,test_size=0.2)

# %%
x_train.shape
# Out:
# (119, 8)

# %%
x_test.shape
# Out:
# (30, 8)

# %%
y_train.shape
# Out:
# (119,)

# %%
y_test.shape
# Out:
# (30,)

# %%
le=LinearRegression()

# %%
le.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
pred_train=le.predict(x_train)

# %%
pred_train
# Out:
# array([6.78733981, 6.93964917, 5.48477324, 7.27953584, 6.02993495,
#        4.75436091, 5.81737946, 6.69913741, 7.4483274 , 6.32596029,
#        4.33477998, 5.07714828, 5.02231205, 7.02645876, 7.33378861,
#        5.09588518, 4.04251428, 3.73774238, 5.10468864, 4.68083813,
#        4.75539522, 4.62585993, 5.43917991, 7.65859225, 3.7134907 ,
#        5.41079403, 6.58154287, 6.0406428 , 6.06077401, 5.73455848,
#        4.28970128, 6.79532747, 6.87053716, 6.77084562, 4.97861537,
#        6.02521872, 4.88975752, 3.90869124, 6.05276004, 4.8454328 ,
#        4.62561154, 6.33103222, 4.8554454 , 3.6146615 , 5.76818197,
#        5.14991866, 4.37576357, 5.79832113, 7.40775981, 3.53884501,
#        3.86077118, 5.75458083, 6.36078797, 5.07094405, 5.25333356,
#        6.49091804, 4.52677444, 7.33225688, 6.15051771, 5.18599721,
#        4.91824819, 5.05904651, 4.00031312, 3.94286784, 4.94400864,
#        7.20887753, 7.10951556, 4.63678903, 4.21362636, 7.60489395,
# ...

# %%
pred_test=le.predict(x_test)

# %%
pred_test
# Out:
# array([5.20327731, 7.05044679, 4.5390434 , 5.11430881, 5.10971392,
#        6.45339974, 5.49896885, 3.74239017, 5.54522929, 5.05759913,
#        4.65309436, 7.32954653, 6.3366386 , 7.31668959, 6.85681408,
#        5.77985148, 3.86020422, 5.45126271, 5.73781371, 4.07973146,
#        6.52131736, 4.45409412, 6.65720467, 4.25557816, 4.19667185,
#        3.71369563, 4.59080687, 4.70968049, 5.89530003, 6.47801228])

# %%
from sklearn.metrics import r2_score

# %%
r2= r2_score(y_test,pred_test)
print(r2)
# Out:
# 0.9962654304733217

# %%
from sklearn.metrics import mean_absolute_error

# %%
print('mean squared error: %.2f'% mean_absolute_error(y_test,pred_test))
# Out:
# mean squared error: 0.05

# %%
from sklearn.model_selection import GridSearchCV

# %%
from sklearn.svm import SVR
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.neighbors import KNeighborsRegressor

# %%
dict1={'Kernel':['rbf','poly','linear']}

# %%
model=SVR()

# %%
gd=GridSearchCV(estimator=model,param_grid=dict1 ,cv=5)

# %%
model.fit(x,y)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=model.predict(x_test)

# %%
y_pred
# Out:
# array([5.286, 6.937, 4.512, 5.192, 5.212, 6.477, 5.605, 3.781, 5.474,
#        5.124, 4.642, 7.2  , 6.298, 7.284, 6.901, 5.813, 3.904, 5.429,
#        5.824, 4.033, 6.505, 4.332, 6.67 , 4.252, 4.218, 3.655, 4.633,
#        4.788, 5.975, 6.485])

# %%
print('mean squared error: %.2f'% mean_absolute_error(y_test,y_pred))
# Out:
# mean squared error: 0.00

# %%
model2= RandomForestRegressor()

# %%
model2.fit(x,y)
# Out:
# RandomForestRegressor()

# %%
y_pred=model2.predict(x_test)
y_pred
# Out:
# array([5.36799, 6.83134, 4.52336, 5.16283, 5.20341, 6.38718, 5.65194,
#        3.90016, 5.73403, 5.11643, 4.54026, 7.22263, 6.32542, 7.2571 ,
#        6.86656, 5.75271, 3.97437, 5.48911, 5.80994, 4.13053, 6.4814 ,
#        4.39314, 6.52995, 4.19845, 4.45509, 3.78482, 4.64926, 4.86599,
#        5.94889, 6.52796])

# %%
print('mean absolute error: %.2f'% mean_absolute_error(y_test,y_pred))
# Out:
# mean absolute error: 0.07

# %%
model3= KNeighborsRegressor()

# %%
model3.fit(x,y)
# Out:
# KNeighborsRegressor()

# %%
y_pred=model3.predict(x_test)

# %%
y_pred
# Out:
# array([4.977 , 6.9206, 4.2986, 5.2722, 5.2528, 6.3568, 5.2072, 3.9244,
#        6.243 , 5.0324, 4.789 , 7.241 , 6.1108, 7.2918, 7.134 , 5.5174,
#        3.9562, 5.6552, 5.7486, 4.2338, 6.275 , 4.104 , 6.341 , 4.1772,
#        4.7798, 3.8142, 4.5488, 4.8592, 5.7452, 6.6008])

# %%
print('mean absolute error: %.2f'% mean_absolute_error(y_test,y_pred))
# Out:
# mean absolute error: 0.19

# %% [markdown]
# As we can see DecisionTreeRegressor is best fitting the model.
